# %% [markdown]
# <a href="https://colab.research.google.com/github/123franklin321/cienciasdedados/blob/master/Webscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
wiki = 'https://www.oracle.com/br/what-is-data-science/'

# %%
page = urllib.request.urlopen(wiki)

# %%
soup = BeautifulSoup(page, 'html5lib')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="no-js" lang="pt-BR">\n <!-- start : Framework/Redwood2 -->\n <!-- start : ocom/common/global/components/framework/head -->\n <head>\n  <!-- start : ocom/common/global/components/head -->\n  <title>\n   O que é Ciência de Dados? | Oracle Brasil\n  </title>\n  <meta content="O que é Ciência de Dados? | Oracle Brasil" name="Title"/>\n  <meta content="A ciência de dados é uma tecnologia utilizada para extrair dados estatísticos, métodos científicos e análises de dados. Acesse o site para saber mais!" name="Description"/>\n  <meta content="ciência de dados, ciência de dados e inteligência artificial, ciência dos dados, ciência de dados e análise de comportamento, ciência de dados e big data" name="Keywords"/>\n  <meta content="br" name="siteid"/>\n  <meta content="BR" name="countryid"/>\n  <meta content="index, follow" name="robots"/>\n  <meta content="Brasil" name="country"/>\n  <meta content="pt" name="Language"/>\n  <meta content="2014-04-24T22:54:05Z" name="Updated Date"/>\n  <script type="text/javascript">\n   var pageData = pageData || {};\n//page info\npageData.pageInfo = pageData.pageInfo || {};\npageData.pageInfo.language = "pt";\npageData.pageInfo.country = "Brasil";\npageData.pageInfo.pageTitle = "O que é Ciência de Dados? | Oracle";\npageData.pageInfo.description = "A ciência de dados é uma tecnologia utilizada para extrair dados estatísticos, métodos científicos e análises de dados. Acesse o site para saber mais!";\npageData.pageInfo.keywords = "ciência de dados, ciência de dados e inteligência artificial, ciência dos dados, ciência de dados e análise de comportamento, ciência de dados e big data";\npageData.pageInfo.siteId = "br";\npageData.pageInfo.countryId = "BR";\npageData.pageInfo.updatedDate = "2014-04-24T22:54:05Z";\n  </script>\n  <!-- start : ocom/common/global/components/seo-taxonomy-meta-data-->\n  <script type="text/javascript">\n   var pageData = pageData || {};\n//taxonmy\npageData.taxonomy = pageData.taxonomy || {};\npageData.taxonomy.productServices = [];\npageData.taxonomy.industry = [];\npageData.taxonomy.region = [];\npageData.taxonomy.contentType = [];\npageData.taxonomy.buyersJourney = [];\npageData.taxonomy.revenue = [];\npageData.taxonomy.title = [];\npageData.taxonomy.audience = [];\npageData.taxonomy.persona = [];\n  </script>\n  <!-- end : ocom/common/global/components/seo-taxonomy-meta-data-->\n  <!-- start : ocom/common/global/components/social-media-meta-tags -->\n  <!-- F13v0 -->\n  <meta content="O que é Ciência de Dados?" property="og:title"/>\n  <meta content="Saiba por que a ciência de dados se tornou uma tecnologia líder necessária para incluir a análise de dados coletados da web, smartphones, clientes, sensores e outras fontes." property="og:description"/>\n  <meta content="https://www.oracle.com/a/ocom/img/social-og-oracle-logo-default-1200x628.png" property="og:image"/>\n  <!-- /F13v0 -->\n  <!-- F13v1 -->\n  <meta content="summary" name="twitter:card"/>\n  <meta content="O que é Ciência de Dados?" name="twitter:title"/>\n  <meta content="Saiba por que a ciência de dados se tornou uma tecnologia líder necessária para incluir a análise de dados coletados da web, smartphones, clientes, sensores e outras fontes." name="twitter:description"/>\n  <meta content="https://www.oracle.com/a/ocom/img/social-og-oracle-logo-default-1200x1200.png" name="twitter:image"/>\n  <!-- /F13v1 -->\n  <!-- end : ocom/common/global/components/social-media-meta-tags -->\n  <!-- start : ocom/common/global/components/seo-hreflang-meta-tags -->\n  <link href="https://www.oracle.com/br/what-is-data-science/" rel="canonical"/>\n  <link href="https://www.oracle.com/ae/what-is-data-science/" hreflang="en-AE" rel="alternate"/>\n  <link href="https://www.oracle.com/ae-ar/what-is-data-science/" hreflang="ar-AE" rel="alternate"/>\n  <link href="https://www.oracle.com/ar/what-is-data-science/" hreflang="es-AR" rel="alternate"/>\n  <link href="https://www.oracle.com/au/what-is-data-scienc ...

# %%
print(soup.title)
# Out:
# <title>O que é Ciência de Dados? | Oracle Brasil</title>

# %%
print(soup.title.string)
# Out:
# O que é Ciência de Dados? | Oracle Brasil

# %%
print(soup.find_all('a'))
# Out:
# [<a href="/br/corporate/accessibility/" id="u30acc">Clique para ver nossa política de acessibilidade</a>, <a href="#maincontent" id="u30skip2c">Ir para o conteúdo</a>, <a aria-label="Home" data-lbl="logo" href="/br/" id="u30btitle">
# <div id="u30logo">
# <svg class="u30-oicn" height="21" style="display:block" viewBox="0 0 32 21" width="32" xmlns="http://www.w3.org/2000/svg"><path d="M9.9,20.1c-5.5,0-9.9-4.4-9.9-9.9c0-5.5,4.4-9.9,9.9-9.9h11.6c5.5,0,9.9,4.4,9.9,9.9c0,5.5-4.4,9.9-9.9,9.9H9.9 M21.2,16.6c3.6,0,6.4-2.9,6.4-6.4c0-3.6-2.9-6.4-6.4-6.4h-11c-3.6,0-6.4,2.9-6.4,6.4s2.9,6.4,6.4,6.4H21.2" fill="#C74634"></path></svg>
# </div>
# </a>, <a data-lbl="Logotxt" href="/br/cloud/" id="u30btxt">
# <svg height="19" id="u30brandtxt" viewBox="0 0 38.14 18.12" width="39" xmlns="http://www.w3.org/2000/svg"><path d="M8.16,18.12a7.76,7.76,0,0,1-6.05-2.35A9.79,9.79,0,0,1,0,9.05,9.58,9.58,0,0,1,2.14,2.38,7.65,7.65,0,0,1,8.16,0a7.65,7.65,0,0,1,6,2.38,9.58,9.58,0,0,1,2.14,6.67,9.79,9.79,0,0,1-2.11,6.72A7.71,7.71,0,0,1,8.16,18.12Zm0-3.19a3.69,3.69,0,0,0,3.24-1.51,7.48,7.48,0,0,0,1.08-4.37A7.37,7.37,0,0,0,11.4,4.7,3.69,3.69,0,0,0,8.16,3.19,3.75,3.75,0,0,0,4.9,4.7,7.45,7.45,0,0,0,3.84,9.05,7.56,7.56,0,0,0,4.9,13.42,3.75,3.75,0,0,0,8.16,14.93ZM32,14v3.12a11.25,11.25,0,0,1-2.19.72,10.85,10.85,0,0,1-2.71.31q-4.2,0-6.36-2.38T18.54,8.86A9.81,9.81,0,0,1,19.6,4.13a7.18,7.18,0,0,1,3-3A9.38,9.38,0,0,1,27.23,0a10.19,10.19,0,0,1,2.35.26,9,9,0,0,1,1.9.68V4.1a15.34,15.34,0,0,0-2.21-.67,8.49,8.49,0,0,0-1.78-.19A4.85,4.85,0,0,0,23.7,4.7a6,6,0,0,0-1.32,4.16,6.85,6.85,0,0,0,1.3,4.48,4.66,4.66,0,0,0,3.81,1.56,10.24,10.24,0,0,0,2-.21A22.73,22.73,0,0,0,32,14Zm2.44,3.81V.34h3.74V17.78Z" fill="#ffffff"></path></svg>
# </a>, <a aria-controls="u30navw1" aria-expanded="false" aria-haspopup="true" href="/br/oci-menu-v2/" id="u30ham" role="button">
# <svg height="24" preserveAspectRatio="none" viewBox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <title>Menu</title>
# <path class="p1" d="M16,4 L2,4"></path>
# <path class="p2" d="M2,12 L22,12"></path>
# <path class="p3" d="M2,20 L16,20"></path>
# <path class="p4" d="M0,12 L24,12"></path>
# <path class="p5" d="M0,12 L24,12"></path>
# </svg>
# <span>Menu</span>
# </a>, <a aria-label="Entre em Contato" class="u30contactBtn" data-lbl="contact-us" href="/br/corporate/contact/" title="Entre em Contato">
# <span>Entre em Contato</span>
# <svg height="24" viewBox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M15.9,3V14h-9L4.81,17H3.09V3ZM8.12,14v3.94l9,.07,2.11,2.92H21V7L15.9,7"></path></svg>
# </a>, <a class="u30cloud" data-lbl="sign-in-account" href="/br/cloud/sign-in.html">
# <svg height="24" viewBox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M17,19.51A3,3,0,0,0,14,17H10a3,3,0,0,0-3,2.51m9.92,0a9,9,0,1,0-9.92,0m9.92,0a9,9,0,0,1-9.92,0M15,10a3,3,0,1,1-3-3A3,3,0,0,1,15,10Z"></path></svg>
# <span class="acttxt">Faça login na Oracle Cloud</span>
# </a>, <a href="https://www.oracle.com/br/index.html">Oracle Brasil</a>, <a data-adbtrack=":ow:o:s:lb::WhatIsDataScience" data-cxdtrack=":ow:o:s:lb::WhatIsDataScience" data-lbl="cloud-free-tier-signup" href="/br/cloud/free/">Inscreva-se agora mesmo</a>, <a href="#process">Quem supervisiona o processo de ciência de dados?</a>, <a href="#what">O que é um cientista de dados?</a>, <a href="#challenges">Desafios de implementação de projetos de ciência de dados</a>, <a href="#capabilities">A plataforma de ciência de dados oferece novos recursos</a>, <a href="#benefits">Os benefícios de uma plataforma de ciência de dados</a>, <a href="#needs">O que um cientista de dados precisa em uma plataforma</a>, <a href="#move">Quando uma plataforma de ciência de dados é a medida certa</a>, <a data-lbl="data-science-lifecycle" href="/br/a/ocom/docs/data-science-lifecycle-ebook-pt-br.pdf" target="_blank">Saiba mais sobre o ciclo de vida da ciência de dados (PDF)</a>, <a data-lbl="data-science-platforms" href="/br/data-science/">plataformas de ciência de dados</a>, <a data-lbl="citizen-data-scientists" href="//blogs.gartner.com/carlie-idoine/2018/05/13/citizen-data-scientists-and-why-they-matter/">cientistas de dados do cidadão</a>, <a data-lbl="data-engineers" href="https://blogs.oracle.com/datascience/ai-influencer-blog-series-why-data-engineering-is-crucial-to-scalable-data-science-v2">engenheiros de dados</a>, <a data-lbl="platform-market" href="https://www.analyticsinsight.net/top-10-data-science-platforms-that-cash-the-analytics-code/" target="_blank">o mercado de plataformas deverá crescer</a>, <a data-lbl="data-science-platform" href="/br/artificial-intelligence/">ciência de dados</a>, <a data-lbl="resources-for:career" href="/br/corporate/careers/">Carreiras</a>, <a data-lbl="resources-for:developers" href="https://developer.oracle.com/pt-BR/">Desenvolvedores</a>, <a data-lbl="resources-for:investors" href="https://investor.oracle.com/home/default.aspx">Investidores</a>, <a data-lbl="resources-for:partners" href="/br/partner/">Parceiros</a>, <a data-lbl="resources-for:startups" href="/br/cloud/oracle-for-startups/">Inicializações</a>, <a data-lbl="resources-for:students-educators" href="https://academy.oracle.com/en/oa-web-overview.html">Alunos e Educadores</a>, <a data-lbl="why-oracle:analyst-reports" href="/br/corporate/analyst-reports/">Relatórios de Analistas</a>, <a data-lbl="why-oracle:oracle-multicloud" href="/br/cloud/cloud-deployment-models/">Oracle Multicloud</a>, <a data-lbl="why-oracle:oci-microsoft-azure" href="/br/cloud/azure/">OCI | Microsoft Azure</a>, <a data-lbl="why-oracle:cloud-reference-architectures" href="https://docs.oracle.com/solutions/">Arquiteturas de referência de nuvem</a>, <a data-lbl="why-oracle:corporate-responsibility" href="/br/corporate/citizenship/">Responsabilidade Corporativa</a>, <a data-lbl="why-oracle:diversity-inclusion" href="/br/corporate/careers/diversity-inclusion/">Diversidade e Inclusão</a>, <a data-lbl="why-oracle:security-pracitices" href="/br/corporate/security-practices/">Práticas de segurança</a>, <a data-lbl="learn:ai" href="/br/artificial-intelligence/what-is-ai/">O que é IA?</a>, <a data-lbl="learn:cloud-computing" href="/br/cloud/what-is-cloud-computing/">O que é computação em nuvem?</a>, <a data-lbl="learn:cloud-storage" href="/br/cloud/storage/what-is-cloud-storage/">O que é armazenamento em nuvem?</a>, <a data-lbl="learn:hpc" href="/br/cloud/hpc/what-is-hpc/">O que é HPC?</a>, <a data-lbl="learn:iaas" href="/br/cloud/what-is-iaas/">O que é IaaS?</a>, <a data-lbl="learn:paas" href="/br/cloud/what-is-paas/">O que é PaaS?</a>, <a data-lbl="whatsnew:cloudworld" href="/br/cloudworld/">Oracle CloudWorld</a>, <a data-adbtrack=":ow:o:h:nav:092121OCISiteFooter" data-cxdtrack=":ow:o:h:nav:092121OCISiteFooter" data-lbl="whatsnew:cloud-free-tier" href="/br/cloud/free/">Modo gratuito da OCI Cloud</a>, <a data-lbl="whatsnew:cloud-architecture-center" href="/br/cloud/architecture-center/">Cloud ...

# %%
all_links = soup.find_all('a')
for link in all_links:
    print(link.get('href'))
# Out:
# /br/corporate/accessibility/
# #maincontent
# /br/
# /br/cloud/
# /br/oci-menu-v2/
# /br/corporate/contact/
# /br/cloud/sign-in.html
# https://www.oracle.com/br/index.html
# /br/cloud/free/
# #process
# #what
# #challenges
# #capabilities
# #benefits
# #needs
# #move
# /br/a/ocom/docs/data-science-lifecycle-ebook-pt-br.pdf
# /br/data-science/
# //blogs.gartner.com/carlie-idoine/2018/05/13/citizen-data-scientists-and-why-they-matter/
# https://blogs.oracle.com/datascience/ai-influencer-blog-series-why-data-engineering-is-crucial-to-scalable-data-science-v2
# https://www.analyticsinsight.net/top-10-data-science-platforms-that-cash-the-analytics-code/
# /br/artificial-intelligence/
# /br/corporate/careers/
# https://developer.oracle.com/pt-BR/
# https://investor.oracle.com/home/default.aspx
# /br/partner/
# /br/cloud/oracle-for-startups/
# https://academy.oracle.com/en/oa-web-overview.html
# /br/corporate/analyst-reports/
# /br/cloud/cloud-deployment-models/
# /br/cloud/azure/
# https://docs.oracle.com/solutions/
# /br/corporate/citizenship/
# /br/corporate/careers/diversity-inclusion/
# /br/corporate/security-practices/
# /br/artificial-intelligence/what-is-ai/
# /br/cloud/what-is-cloud-computing/
# /br/cloud/storage/what-is-cloud-storage/
# /br/cloud/hpc/what-is-hpc/
# /br/cloud/what-is-iaas/
# /br/cloud/what-is-paas/
# /br/cloudworld/
# /br/cloud/free/
# /br/cloud/architecture-center/
# /br/cloud/cloud-lift/
# /br/cloud/rewards/
# /br/redbullracing/
# tel:08008914433
# /br/corporate/contact/
# https://go.oracle.com/subscribe/?l_code=pt&src1=OW:O:FO
# /br/cloud/events/
# /br/news/
# https://blogs.oracle.com/cloud-infrastructure/
# /br/menu-content/universal.html#u10countrymenu
# /br/legal/copyright.html
# /br/legal/privacy/
# /br/legal/privacy/advertising-privacy-policy.html#adchoices
# /br/corporate/careers/
# https://www.facebook.com/oraclebrasil/
# https://twitter.com/oracledobrasil
# https://www.linkedin.com/company/oracle/
# https://www.youtube.com/user/oracledobrasil
