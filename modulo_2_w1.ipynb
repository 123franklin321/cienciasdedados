# %% [markdown]
# <a href="https://colab.research.google.com/github/123franklin321/cienciasdedados/blob/master/modulo_2_w1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import os

# %%
diretorio = './'
lista_de_arquivos = os.listdir('./')
lista_de_arquivos
# Out:
# ['.config',
#  'olist_orders_dataset.csv',
#  'olist_sellers_dataset.csv',
#  'olist_customers_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_order_reviews_dataset.csv',
#  'olist_order_payments_dataset.csv',
#  'product_category_name_translation.csv',
#  'olist_products_dataset.csv',
#  'olist_geolocation_dataset.csv',
#  'sample_data']

# %%
arquivo = lista_de_arquivos[1]
arquivo
# Out:
# 'olist_orders_dataset.csv'

# %%
caminho_do_arquivo = diretorio + arquivo

# %%
df = pd.read_csv(caminho_do_arquivo)

# %%
df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df) == pd.core.frame.DataFrame
# Out:
# True

# %%
dir(pd.core.frame.DataFrame)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
help(pd.core.frame.DataFrame.info)
# Out:
# Help on function info in module pandas.core.frame:
#
# info(self, verbose: 'bool | None' = None, buf: 'IO[str] | None' = None, max_cols: 'int | None' = None, memory_usage: 'bool | str | None' = None, show_counts: 'bool | None' = None, null_counts: 'bool | None' = None) -> 'None'
#     Print a concise summary of a DataFrame.
#
#     This method prints information about a DataFrame including
#     the index dtype and columns, non-null values and memory usage.
#
#     Parameters
#     ----------
#     data : DataFrame
#         DataFrame to print information about.
#     verbose : bool, optional
#         Whether to print the full summary. By default, the setting in
#         ``pandas.options.display.max_info_columns`` is followed.
#     buf : writable buffer, defaults to sys.stdout
#         Where to send the output. By default, the output is printed to
#         sys.stdout. Pass a writable buffer if you need to further process
#         the output.
#     max_cols : int, optional
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
colunas = df.columns
colunas
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
dir(colunas)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__inv__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
# ...

# %%
colunas = df.columns.to_list()
colunas
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'order_purchase_timestamp',
#  'order_approved_at',
#  'order_delivered_carrier_date',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date']

# %%
colunas_nome_contem_date = [col for col in colunas if 'date' in col]
colunas_nome_contem_date
# Out:
# ['order_delivered_carrier_date',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date']

# %%
df['order_status']
# Out:
# 0        delivered
# 1        delivered
# 2        delivered
# 3        delivered
# 4        delivered
#            ...
# 99436    delivered
# 99437    delivered
# 99438    delivered
# 99439    delivered
# 99440    delivered
# Name: order_status, Length: 99441, dtype: object

# %%
df[colunas_nome_contem_date]
# Out:
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date
# 0               2017-10-18 00:00:00
# 1               2018-08-13 00:00:00
# 2               2018-09-04 00:00:00
# 3               2017-12-15 00:00:00
# ...

# %%
situacao_pedido = df[['order_status']]
situacao_pedido
# Out:
#       order_status
# 0        delivered
# 1        delivered
# 2        delivered
# 3        delivered
# 4        delivered
# ...            ...
# 99436    delivered
# 99437    delivered
# 99438    delivered
# 99439    delivered
# 99440    delivered
#
# [99441 rows x 1 columns]

# %%
type(situacao_pedido)
# Out:
# pandas.core.frame.DataFrame

# %%
situacao_pedido.sort_values(by='order_status')
# Out:
#       order_status
# 44897     approved
# 88457     approved
# 26197     canceled
# 56996     canceled
# 29738     canceled
# ...            ...
# 22128  unavailable
# 33137  unavailable
# 10928  unavailable
# 33157  unavailable
# 6611   unavailable
#
# [99441 rows x 1 columns]

# %%
df.sort_values(by='order_status')
# Out:
#                                order_id                       customer_id  \
# 44897  a2e4c44360b4a57bdff22f3a4630c173  8886130db0ea6e9e70ba0b03d7c0d286
# 88457  132f1e724165a07f6362532bfb97486e  b2191912d8ad6eac2e4dc3b6e1459515
# 26197  5b3367de06e5c2955a98de36a52fbe1a  efccddae70862d3630a35e4c7fc75a02
# 56996  552e0a8dae101e32155120202f427b71  d1167e026b86aff77a4599738bf972dd
# 29738  cd94dbdc801da0cd93b0c8f33663973d  17ba50f54399b61694fbb138a3831d56
# ...                                 ...                               ...
# 22128  b210c676cae65f95f7e08a49d195e1a1  44cb55a7202fc9fccf83f653373bb000
# 33137  6111350dd1f8b825ac82e9caea339f07  d46ae795ce93d1cec2f41eea68a58982
# 10928  97b22dcad89f4916db427544e655d1b2  a746c825432e5eaf2b8eeece33ca54b7
# 33157  dc18a044b56ed174037ca164cdf2e921  4a06381959b6670756de02e07b83815f
# 6611   f2a335c81aebf64a9a4309436e7af4a8  cca8b12b9e669afd8a28ff57fd5c5e75
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df.loc[2]
# Out:
# order_id                         47770eb9100c2d0c44946d9cf07ec65d
# customer_id                      41ce2a54c0b03bf3443c3d931a367089
# order_status                                            delivered
# order_purchase_timestamp                      2018-08-08 08:38:49
# order_approved_at                             2018-08-08 08:55:23
# order_delivered_carrier_date                  2018-08-08 13:50:00
# order_delivered_customer_date                 2018-08-17 18:06:29
# order_estimated_delivery_date                 2018-09-04 00:00:00
# Name: 2, dtype: object

# %%
df.loc[[2,3,4]]
# Out:
#                            order_id                       customer_id  \
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
df.loc[[2]].sort_values(by='order_status')
# Out:
#                            order_id                       customer_id  \
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date
# 2           2018-09-04 00:00:00

# %%
df.loc[:, ['order_id']]
# Out:
#                                order_id
# 0      e481f51cbdc54678b7cc49136f2d6af7
# 1      53cdb2fc8bc7dce0b6741e2150273451
# 2      47770eb9100c2d0c44946d9cf07ec65d
# 3      949d5b44dbf5de918fe9c16f97b45f8a
# 4      ad21c59c0840e6cb83a9ceb5573f8159
# ...                                 ...
# 99436  9c5dedf39a927c1b2549525ed64a053c
# 99437  63943bddc261676b46f01ca7ac2f7bd8
# 99438  83c1379a015df1e13d02aae0204711ab
# 99439  11c177c8e97725db2631073c19f07b62
# 99440  66dea50a8b16d9b4dee7af250b4be1a5
#
# [99441 rows x 1 columns]

# %%
df.loc[[1,2,10], ['order_id', 'order_status']]
# Out:
#                             order_id order_status
# 1   53cdb2fc8bc7dce0b6741e2150273451    delivered
# 2   47770eb9100c2d0c44946d9cf07ec65d    delivered
# 10  e6ce16cb79ec1d90b1da9085a6118aeb    delivered

# %%
alguns_pedidos = df.loc[[2,26197,88457]].sort_values(by='order_status')
alguns_pedidos
# Out:
#                                order_id                       customer_id  \
# 88457  132f1e724165a07f6362532bfb97486e  b2191912d8ad6eac2e4dc3b6e1459515
# 26197  5b3367de06e5c2955a98de36a52fbe1a  efccddae70862d3630a35e4c7fc75a02
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 88457     approved      2017-04-25 01:25:34  2017-04-30 20:32:41
# 26197     canceled      2017-03-07 12:43:03  2017-03-07 13:04:43
# 2        delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 88457                          NaN                           NaN
# 26197                          NaN                           NaN
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
#
#       order_estimated_delivery_date
# 88457           2017-05-22 00:00:00
# 26197           2017-03-28 00:00:00
# ...

# %%
alguns_pedidos.iloc[:, [0,2]]
# Out:
#                                order_id order_status
# 88457  132f1e724165a07f6362532bfb97486e     approved
# 26197  5b3367de06e5c2955a98de36a52fbe1a     canceled
# 2      47770eb9100c2d0c44946d9cf07ec65d    delivered

# %%
df['order_status'].unique()
# Out:
# array(['delivered', 'invoiced', 'shipped', 'processing', 'unavailable',
#        'canceled', 'created', 'approved'], dtype=object)

# %%
df.set_index('order_status')
# Out:
#                                       order_id  \
# order_status
# delivered     e481f51cbdc54678b7cc49136f2d6af7
# delivered     53cdb2fc8bc7dce0b6741e2150273451
# delivered     47770eb9100c2d0c44946d9cf07ec65d
# delivered     949d5b44dbf5de918fe9c16f97b45f8a
# delivered     ad21c59c0840e6cb83a9ceb5573f8159
# ...                                        ...
# delivered     9c5dedf39a927c1b2549525ed64a053c
# delivered     63943bddc261676b46f01ca7ac2f7bd8
# delivered     83c1379a015df1e13d02aae0204711ab
# delivered     11c177c8e97725db2631073c19f07b62
# delivered     66dea50a8b16d9b4dee7af250b4be1a5
#
#                                    customer_id order_purchase_timestamp  \
# order_status
# delivered     9ef432eb6251297304e76186b10a928d      2017-10-02 10:56:33
# delivered     b0830fb4747a6c6d20dea0b8c802d7ef      2018-07-24 20:41:37
# delivered     41ce2a54c0b03bf3443c3d931a367089      2018-08-08 08:38:49
# delivered     f88197465ea7920adcdbec7375364d82      2017-11-18 19:28:06
# ...

# %%
df.set_index('order_status').loc['canceled']
# Out:
#                                       order_id  \
# order_status
# canceled      1b9ecfe83cdc259250e1a8aca174f0ad
# canceled      714fb133a6730ab81fa1d3c1b2007291
# canceled      3a129877493c8189c59c60eb71d97c29
# canceled      00b1cb0320190ca0daa2c88b35206009
# canceled      ed3efbd3a87bea76c2812c66a0b32219
# ...                                        ...
# canceled      b159d0ce7cd881052da94fa165617b05
# canceled      e49e7ce1471b4693482d40c2bd3ad196
# canceled      6560fb10610771449cb0463c5ba12199
# canceled      3a3cddda5a7c27851bd96c3313412840
# canceled      a89abace0dcc01eeb267a9660b5ac126
#
#                                    customer_id order_purchase_timestamp  \
# order_status
# canceled      6d6b50b66d79f80827b6d96751528d30      2018-08-04 14:29:27
# canceled      e3fe72696c4713d64d3c10afe71e75ed      2018-01-26 21:34:08
# canceled      0913cdce793684e52bbfac69d87e91fd      2018-01-25 13:34:24
# canceled      3532ba38a3fd242259a514ac2b6ae6b6      2018-08-28 15:26:39
# ...

# %%
df.set_index('order_status').loc[['canceled', 'unavailable']]
# Out:
#                                       order_id  \
# order_status
# canceled      1b9ecfe83cdc259250e1a8aca174f0ad
# canceled      714fb133a6730ab81fa1d3c1b2007291
# canceled      3a129877493c8189c59c60eb71d97c29
# canceled      00b1cb0320190ca0daa2c88b35206009
# canceled      ed3efbd3a87bea76c2812c66a0b32219
# ...                                        ...
# unavailable   6cf5c427fb11bc5fe8abefa86aa7ba0b
# unavailable   1c7c8ab324927f5b6e52338bd110bef4
# unavailable   aaab15da689073f8f9aa978a390a69d1
# unavailable   a69ba794cc7deb415c3e15a0a3877e69
# unavailable   5fabc81b6322c8443648e1b21a6fef21
#
#                                    customer_id order_purchase_timestamp  \
# order_status
# canceled      6d6b50b66d79f80827b6d96751528d30      2018-08-04 14:29:27
# canceled      e3fe72696c4713d64d3c10afe71e75ed      2018-01-26 21:34:08
# canceled      0913cdce793684e52bbfac69d87e91fd      2018-01-25 13:34:24
# canceled      3532ba38a3fd242259a514ac2b6ae6b6      2018-08-28 15:26:39
# ...

# %%
df.set_index('order_status').loc[['canceled', 'unavailable'], ['order_purchase_timestamp', 'order_delivered_customer_date']]
# Out:
#              order_purchase_timestamp order_delivered_customer_date
# order_status
# canceled          2018-08-04 14:29:27                           NaN
# canceled          2018-01-26 21:34:08                           NaN
# canceled          2018-01-25 13:34:24                           NaN
# canceled          2018-08-28 15:26:39                           NaN
# canceled          2018-09-20 13:54:16                           NaN
# ...                               ...                           ...
# unavailable       2017-10-17 10:53:48                           NaN
# unavailable       2017-12-23 18:48:09                           NaN
# unavailable       2018-01-16 14:27:59                           NaN
# unavailable       2017-08-23 16:28:04                           NaN
# unavailable       2017-10-10 10:50:03                           NaN
#
# [1234 rows x 2 columns]

# %%
df['order_status'].value_counts()
# Out:
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_status, dtype: int64

# %%
tipos_de_status = df['order_status'].value_counts(normalize=True)
print(type(tipos_de_status))
tipos_de_status
# Out:
# <class 'pandas.core.series.Series'>
# delivered      0.970203
# shipped        0.011132
# canceled       0.006285
# unavailable    0.006124
# invoiced       0.003158
# processing     0.003027
# created        0.000050
# approved       0.000020
# Name: order_status, dtype: float64

# %%
tipos_de_status.reset_index()
# Out:
#          index  order_status
# 0    delivered      0.970203
# 1      shipped      0.011132
# 2     canceled      0.006285
# 3  unavailable      0.006124
# 4     invoiced      0.003158
# 5   processing      0.003027
# 6      created      0.000050
# 7     approved      0.000020

# %%
for i, f in enumerate(lista_de_arquivos):
    print(i, f)
# Out:
# 0 .config
# 1 olist_orders_dataset.csv
# 2 olist_sellers_dataset.csv
# 3 olist_customers_dataset.csv
# 4 olist_order_items_dataset.csv
# 5 olist_order_reviews_dataset.csv
# 6 olist_order_payments_dataset.csv
# 7 product_category_name_translation.csv
# 8 olist_products_dataset.csv
# 9 olist_geolocation_dataset.csv
# 10 sample_data

# %%
df_pgtos = pd.read_csv(diretorio + lista_de_arquivos[6])
df_pgtos
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
df_pgtos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
df_pgtos['order_id'].describe()
# Out:
# count                               103886
# unique                               99440
# top       fa65dad1b0e818e3ccc5cb0e39231352
# freq                                    29
# Name: order_id, dtype: object

# %%
df_pgtos.set_index('order_id').loc['fa65dad1b0e818e3ccc5cb0e39231352'].sort_values(by='payment_sequential')
# Out:
#                                   payment_sequential payment_type  \
# order_id
# fa65dad1b0e818e3ccc5cb0e39231352                   1      voucher
# fa65dad1b0e818e3ccc5cb0e39231352                   2      voucher
# fa65dad1b0e818e3ccc5cb0e39231352                   3      voucher
# fa65dad1b0e818e3ccc5cb0e39231352                   4      voucher
# fa65dad1b0e818e3ccc5cb0e39231352                   5      voucher
# fa65dad1b0e818e3ccc5cb0e39231352                   6      voucher
# fa65dad1b0e818e3ccc5cb0e39231352                   7      voucher
# fa65dad1b0e818e3ccc5cb0e39231352                   8      voucher
# fa65dad1b0e818e3ccc5cb0e39231352                   9      voucher
# fa65dad1b0e818e3ccc5cb0e39231352                  10      voucher
# fa65dad1b0e818e3ccc5cb0e39231352                  11      voucher
# fa65dad1b0e818e3ccc5cb0e39231352                  12      voucher
# fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# ...

# %%
df_pgtos\
.set_index('order_id')\
.loc['fa65dad1b0e818e3ccc5cb0e39231352']\
.sort_values(by='payment_sequential')\
['payment_value'].describe()
# Out:
# count     29.000000
# mean      15.792759
# std       29.452201
# min        0.000000
# 25%        2.950000
# 50%        4.110000
# 75%       18.860000
# max      150.000000
# Name: payment_value, dtype: float64

# %%
df_pgtos['payment_value'].describe()
# Out:
# count    103886.000000
# mean        154.100380
# std         217.494064
# min           0.000000
# 25%          56.790000
# 50%         100.000000
# 75%         171.837500
# max       13664.080000
# Name: payment_value, dtype: float64

# %%
df_pgtos['payment_installments'].hist(bins=30)

# %%
q90 = df_pgtos['payment_value'].quantile(.90)
q90
# Out:
# 297.27

# %%
pagamentos = df_pgtos['payment_value']
pagamentos
# Out:
# 0          99.33
# 1          24.39
# 2          65.71
# 3         107.78
# 4         128.45
#            ...
# 103881    363.31
# 103882     96.80
# 103883     47.77
# 103884    369.54
# 103885    191.58
# Name: payment_value, Length: 103886, dtype: float64

# %%
pagamentos[pagamentos < q90]
# Out:
# 0          99.33
# 1          24.39
# 2          65.71
# 3         107.78
# 4         128.45
#            ...
# 103879    198.94
# 103880    280.65
# 103882     96.80
# 103883     47.77
# 103885    191.58
# Name: payment_value, Length: 93496, dtype: float64

# %%
pagamentos < q90
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 103881    False
# 103882     True
# 103883     True
# 103884    False
# 103885     True
# Name: payment_value, Length: 103886, dtype: bool

# %%
selecao = pagamentos < q90

pagamentos.loc[selecao].hist()

# %%
pagamentos.agg(['max','min','sum','mean'])
# Out:
# max     1.366408e+04
# min     0.000000e+00
# sum     1.600887e+07
# mean    1.541004e+02
# Name: payment_value, dtype: float64

# %%
df_pgtos_grouped = df_pgtos.groupby(['payment_type'])
df_pgtos_grouped

# %%
type(df_pgtos_grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df_pgtos_grouped[['payment_value']].sum()
# Out:
#               payment_value
# payment_type
# boleto           2869361.27
# credit_card     12542084.19
# debit_card        217989.79
# not_defined            0.00
# voucher           379436.87

# %%
df_pgtos_grouped[['payment_value']].agg(['sum', 'mean'])
# Out:
#              payment_value
#                        sum        mean
# payment_type
# boleto          2869361.27  145.034435
# credit_card    12542084.19  163.319021
# debit_card       217989.79  142.570170
# not_defined           0.00    0.000000
# voucher          379436.87   65.703354

# %%
df_pgtos_grouped[['payment_value']].agg(['sum', 'mean'])[('payment_value', 'sum')]
# Out:
# payment_type
# boleto          2869361.27
# credit_card    12542084.19
# debit_card       217989.79
# not_defined           0.00
# voucher          379436.87
# Name: (payment_value, sum), dtype: float64

# %%
df_pgtos_grouped[['payment_value']].agg(['sum', 'mean'])[('payment_value', 'sum')].sum()
# Out:
# 16008872.119999997
