# %% [markdown]
# <a href="https://colab.research.google.com/github/123franklin321/cienciasdedados/blob/master/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
 
time = mdates.drange(dt.datetime(2014, 12, 20), dt.datetime(2015, 1, 2),
                     dt.timedelta(hours=2))
y = np.random.normal(0, 1, time.size).cumsum()
y -= y.min()
 
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(time, y, 'bo-')
ax.set(title='Active Calls', ylabel='Calls', xlabel='Time')
ax.grid()
 
ax.xaxis_date()
fig.autofmt_xdate()
 
plt.show()

# %%
from re import X
x = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
y= [300.2, 543.3, 1075.9, 2862.5, 5979.0, 10289.7, 14958.6]

# %%
plt.plot(x, y)
plt.title('Pib Nominal')
plt.ylabel('Billions of $')
plt.show()

# %%
import plotly.express as px 
plt.style.use('seaborn')

# %%
movies = ['Annie Hall', 'Ben Hur', 'Casablanca', 'Gandhi', 'West Slid Story']
num_oscars = [5, 11, 3, 8, 10]

# %%
plt.bar(range(len(movies)), num_oscars)
plt.title('My Favorite Movies')
plt.ylabel('of Academy Awards')
plt.xticks(range(len(movies)), movies)
plt.show()
